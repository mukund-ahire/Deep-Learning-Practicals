# %% [markdown]
# Aim: Implementing feedforward neural network with keras and tenserflow a.Import the necessary packages b. Load the training and testing data
#           c. Define the network architecture with keras d.Train the model using sgd e. Evaluate the network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
import matplotlib.pyplot as plt

# %% [markdown]
# Cell 2: Loading and Preprocessing Data

# %%
# MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()  # Data Loading
x_train, x_test = x_train/255.0, x_test/255.0  # Normalizing the data
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Cell 3: Plotting an Example

# %%
# Plotting an example
plt.imshow(x_train[0])
plt.show()

# %% [markdown]
# Cell 4: Preparing the Model

# %%
# Preparing the model
model = Sequential([
    Input(shape=(28, 28)),
    Flatten(),
    Dense(120, activation="relu"),
    Dropout(0.2),
    Dense(10)
])

# %% [markdown]
# Cell 5: Making Predictions

# %%
# Making predictions
predictions = model(x_train[:1]).numpy()
print(predictions)
# Out:
# [[ 0.04486334 -0.7851291  -0.20178913  0.00363003 -0.3435491   0.23546743
#   -0.2320739   0.3545092   0.39430872  0.4417868 ]]

# %% [markdown]
# Cell 6: Applying Softmax

# %%
# Applying softmax
print(tf.nn.softmax(predictions).numpy())
# Out:
# [[0.09909084 0.04320882 0.07743079 0.09508809 0.06719673 0.11989797
#   0.07512097 0.1350551  0.14053863 0.14737207]]

# %% [markdown]
# Cell 7: Defining Loss Function

# %%
# Loss function
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %% [markdown]
# Cell 8: Compiling the Model

# %%
# Compiling the model
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %% [markdown]
# Cell 9: Training the Model

# %%
# Training the model
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8624 - loss: 0.4871
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9561 - loss: 0.1501
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9686 - loss: 0.1062
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9715 - loss: 0.0888
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9754 - loss: 0.0771

# %% [markdown]
# Cell 10: Evaluating the Model

# %%
# Evaluating the model
model.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 0s - 1ms/step - accuracy: 0.9744 - loss: 0.0816
# [0.08161040395498276, 0.974399983882904]

# %% [markdown]
# Cell 11: Validation of Model and Plotting Accuracy

# %%
# Validation of Model
val = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test), batch_size=300)
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(val.history["accuracy"])
plt.plot(val.history["val_accuracy"])
plt.legend(["train", "val"])
plt.show()
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9805 - loss: 0.0641 - val_accuracy: 0.9796 - val_loss: 0.0665
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9848 - loss: 0.0502 - val_accuracy: 0.9798 - val_loss: 0.0650
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9853 - loss: 0.0494 - val_accuracy: 0.9808 - val_loss: 0.0634
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9853 - loss: 0.0457 - val_accuracy: 0.9810 - val_loss: 0.0630
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9865 - loss: 0.0462 - val_accuracy: 0.9818 - val_loss: 0.0632
